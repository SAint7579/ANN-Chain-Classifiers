# %%
import numpy as np
import warnings
import sys
import pandas as pd
import scipy
from scipy.io import arff
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
data_train, meta = scipy.io.arff.loadarff('scene-train.arff')
df_train = pd.DataFrame(data_train)
data_test, meta = scipy.io.arff.loadarff('scene-test.arff')
df_test = pd.DataFrame(data_test)
df_test.head()
# Out:
#        Att1      Att2      Att3      Att4      Att5      Att6      Att7  \
# 0  0.983225  0.981488  0.978542  0.975908  0.972962  0.968367  0.965900
# 1  0.018160  0.074481  0.369500  0.454558  0.423218  0.379960  0.661803
# 2  0.762800  0.791230  0.799371  0.795679  0.779932  0.756109  0.719042
# 3  0.758518  0.738699  0.709982  0.686717  0.694709  0.687867  0.461537
# 4  0.948445  0.969889  0.965691  0.969223  0.969579  0.966511  0.949118
#
#        Att8      Att9     Att10  ...      Att291    Att292    Att293  \
# 0  0.938807  0.888701  0.862884  ...    0.002494  0.012225  0.045861
# 1  0.653965  0.666010  0.671838  ...    0.005567  0.014649  0.025994
# 2  0.877675  0.907015  0.919592  ...    0.040818  0.051593  0.057795
# 3  0.852653  0.831340  0.798184  ...    0.599021  0.068253  0.061698
# 4  0.823672  0.853659  0.857751  ...    0.001599  0.000875  0.000813
#
#      Att294  Beach  Sunset  FallFoliage  Field  Mountain  Urban
# 0  0.094455   b'1'    b'0'         b'0'   b'0'      b'1'   b'0'
# 1  0.024701   b'1'    b'0'         b'0'   b'0'      b'0'   b'0'
# 2  0.057418   b'1'    b'0'         b'0'   b'0'      b'0'   b'0'
# 3  0.053979   b'1'    b'0'         b'0'   b'0'      b'1'   b'0'
# 4  0.003186   b'1'    b'0'         b'0'   b'0'      b'0'   b'0'
#
# [5 rows x 300 columns]

# %%
X_train = df_train.iloc[:,:-6].values
y_train = df_train.iloc[:,-6:].values.astype(int)
X_test = df_test.iloc[:,:-6].values
y_test = df_test.iloc[:,-6:].values.astype(int)

# %%
print("Train_X: ",X_train.shape)
print("Train_Y: ",y_train.shape)
print("Test_X: ",X_test.shape)
print("Test_Y: ",y_test.shape)
# Out:
# Train_X:  (1211, 294)
# Train_Y:  (1211, 6)
# Test_X:  (1196, 294)
# Test_Y:  (1196, 6)

# %%
def hamming_accuracy_score(y_true, y_pred, normalize=True, sample_weight=None):
    '''
    Compute the Hamming score (a.k.a. label-based accuracy) for the multi-label case
    http://stackoverflow.com/q/32239577/395857
    '''
    acc_list = []
    for i in range(y_true.shape[0]):
        set_true = set( np.where(y_true[i])[0] )
        set_pred = set( np.where(y_pred[i])[0] )
        #print('\nset_true: {0}'.format(set_true))
        #print('set_pred: {0}'.format(set_pred))
        tmp_a = None
        if len(set_true) == 0 and len(set_pred) == 0:
            tmp_a = 1
        else:
            tmp_a = len(set_true.intersection(set_pred))/float( len(set_true.union(set_pred)) )
        #print('tmp_a: {0}'.format(tmp_a))
        acc_list.append(tmp_a)
    return np.mean(acc_list)

# %% [markdown]
# ## Chain Model type 1

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.backend.tensorflow_backend import clear_session
# Out:
# Using TensorFlow backend.

# %%
def create_c1node(X_feed,y_now):
    '''
    C1 node Architecture:
    attribute:512:256:1 [saperate for each class]
    loss: Binary crossentropy
    '''
    model = Sequential()
    model.add(Dense(512,activation='relu',input_shape=(X_feed.shape[1],),kernel_initializer='glorot_uniform'))
    model.add(Dropout(0.4))
    model.add(Dense(256,activation='relu',kernel_initializer='glorot_uniform'))
    model.add(Dropout(0.4))
    model.add(Dense(y_now.shape[1],activation='sigmoid',kernel_initializer='glorot_uniform'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    
    return model

# %%
#Model chain
chain = []

#Training
X_feed = X_train.copy()
for i in range(y_train.shape[1]):
    print("Training chain node ",i)
    y_now = y_train[:,[i,]].copy()
    print("Shapes:\n X = {} \n Y = {}".format(X_feed.shape,y_now.shape))

    node = create_c1node(X_feed,y_now)
    node.fit(X_feed,y_now,epochs=10,batch_size=50)
    print("Training of node {} complete\n\n".format(i))  
    #Checking accuracy of the node
    #---
    #Adding node to chain 
    chain.append(node)
    #Updating X_feed
    X_feed = np.append(X_feed,y_now,axis=1)
# Out:
# Training chain node  0
# Shapes:
#  X = (1211, 294)
#  Y = (1211, 1)
# Epoch 1/10
# 1211/1211 [==============================] - 24s 20ms/step - loss: 0.4618 - acc: 0.7977
# Epoch 2/10
# 1211/1211 [==============================] - 0s 127us/step - loss: 0.3435 - acc: 0.8472
# Epoch 3/10
# 1211/1211 [==============================] - 0s 129us/step - loss: 0.3114 - acc: 0.8596
# Epoch 4/10
# 1211/1211 [==============================] - 0s 129us/step - loss: 0.2852 - acc: 0.8728
# Epoch 5/10
# 1211/1211 [==============================] - 0s 129us/step - loss: 0.2836 - acc: 0.8803
# Epoch 6/10
# 1211/1211 [==============================] - 0s 126us/step - loss: 0.2405 - acc: 0.8960
# Epoch 7/10
# 1211/1211 [==============================] - 0s 133us/step - loss: 0.2345 - acc: 0.8927
# Epoch 8/10
# 1211/1211 [==============================] - 0s 128us/step - loss: 0.2607 - acc: 0.8960
# Epoch 9/10
# 1211/1211 [==============================] - 0s 129us/step - loss: 0.2396 - acc: 0.8927
# Epoch 10/10
# 1211/1211 [==============================] - 0s 130us/step - loss: 0.2051 - acc: 0.9125
# Training of node 0 complete
#
#
# Training chain node  1
# Shapes:
#  X = (1211, 295)
#  Y = (1211, 1)
# Epoch 1/10
# 1211/1211 [==============================] - 1s 436us/step - loss: 0.2874 - acc: 0.8902
# Epoch 2/10
# 1211/1211 [==============================] - 0s 127us/step - loss: 0.1328 - acc: 0.9438
# Epoch 3/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.1067 - acc: 0.9554
# Epoch 4/10
# 1211/1211 [==============================] - 0s 133us/step - loss: 0.0910 - acc: 0.9620
# Epoch 5/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.0744 - acc: 0.9694
# Epoch 6/10
# 1211/1211 [==============================] - 0s 128us/step - loss: 0.0636 - acc: 0.9744
# Epoch 7/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.0816 - acc: 0.9653
# Epoch 8/10
# 1211/1211 [==============================] - 0s 128us/step - loss: 0.0767 - acc: 0.9653
# Epoch 9/10
# 1211/1211 [==============================] - 0s 134us/step - loss: 0.0733 - acc: 0.9670
# Epoch 10/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.0714 - acc: 0.9703
# Training of node 1 complete
#
#
# Training chain node  2
# Shapes:
#  X = (1211, 296)
#  Y = (1211, 1)
# Epoch 1/10
# 1211/1211 [==============================] - 1s 468us/step - loss: 0.3851 - acc: 0.8390
# Epoch 2/10
# 1211/1211 [==============================] - 0s 129us/step - loss: 0.2216 - acc: 0.9100
# Epoch 3/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.1730 - acc: 0.9315
# Epoch 4/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.1384 - acc: 0.9414
# Epoch 5/10
# 1211/1211 [==============================] - 0s 127us/step - loss: 0.1230 - acc: 0.9587
# Epoch 6/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.0930 - acc: 0.9678
# Epoch 7/10
# 1211/1211 [==============================] - 0s 130us/step - loss: 0.0859 - acc: 0.9661
# Epoch 8/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.1003 - acc: 0.9670
# Epoch 9/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.0742 - acc: 0.9694
# Epoch 10/10
# 1211/1211 [==============================] - 0s 135us/step - loss: 0.0786 - acc: 0.9719
# Training of node 2 complete
#
#
# Training chain node  3
# Shapes:
#  X = (1211, 297)
#  Y = (1211, 1)
# Epoch 1/10
# 1211/1211 [==============================] - 1s 496us/step - loss: 0.3954 - acc: 0.8365
# Epoch 2/10
# 1211/1211 [==============================] - 0s 133us/step - loss: 0.1914 - acc: 0.9306
# Epoch 3/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.1643 - acc: 0.9397
# Epoch 4/10
# 1211/1211 [==============================] - 0s 134us/step - loss: 0.1613 - acc: 0.9480
# Epoch 5/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.1436 - acc: 0.9405
# Epoch 6/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.1569 - acc: 0.9496
# Epoch 7/10
# 1211/1211 [==============================] - 0s 133us/step - loss: 0.1316 - acc: 0.9538
# Epoch 8/10
# 1211/1211 [==============================] - 0s 134us/step - loss: 0.1299 - acc: 0.9513
# Epoch 9/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.1184 - acc: 0.9521
# Epoch 10/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.1264 - acc: 0.9480
# Training of node 3 complete
#
#
# Training chain node  4
# Shapes:
#  X = (1211, 298)
#  Y = (1211, 1)
# Epoch 1/10
# 1211/1211 [==============================] - 1s 524us/step - loss: 0.5316 - acc: 0.7498
# Epoch 2/10
# 1211/1211 [==============================] - 0s 128us/step - loss: 0.4350 - acc: 0.7803
# Epoch 3/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.3996 - acc: 0.8068
# Epoch 4/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.3954 - acc: 0.8068
# Epoch 5/10
# 1211/1211 [==============================] - 0s 134us/step - loss: 0.3725 - acc: 0.8282
# Epoch 6/10
# 1211/1211 [==============================] - 0s 131us/step - loss: 0.3093 - acc: 0.8646
# Epoch 7/10
# 1211/1211 [==============================] - 0s 139us/step - loss: 0.3101 - acc: 0.8671
# Epoch 8/10
# 1211/1211 [==============================] - 0s 139us/step - loss: 0.2988 - acc: 0.8728
# Epoch 9/10
# 1211/1211 [==============================] - 0s 134us/step - loss: 0.2906 - acc: 0.8728
# Epoch 10/10
# 1211/1211 [==============================] - 0s 132us/step - loss: 0.2880 - acc: 0.8728
# Training of node 4 complete
#
#
# Training chain node  5
# Shapes:
#  X = (1211, 299)
#  Y = (1211, 1)
# Epoch 1/10
# 1211/1211 [==============================] - 1s 642us/step - loss: 0.4378 - acc: 0.7903
# Epoch 2/10
# 1211/1211 [==============================] - 0s 134us/step - loss: 0.2917 - acc: 0.8770
# Epoch 3/10
# 1211/1211 [==============================] - 0s 146us/step - loss: 0.2333 - acc: 0.9042
# Epoch 4/10
# 1211/1211 [==============================] - 0s 154us/step - loss: 0.1718 - acc: 0.9290
# Epoch 5/10
# 1211/1211 [==============================] - 0s 161us/step - loss: 0.1453 - acc: 0.9381
# Epoch 6/10
# 1211/1211 [==============================] - 0s 157us/step - loss: 0.1196 - acc: 0.9579
# Epoch 7/10
# 1211/1211 [==============================] - 0s 176us/step - loss: 0.0770 - acc: 0.9752
# Epoch 8/10
# 1211/1211 [==============================] - 0s 184us/step - loss: 0.0737 - acc: 0.9794
# Epoch 9/10
# 1211/1211 [==============================] - 0s 185us/step - loss: 0.0665 - acc: 0.9785
# Epoch 10/10
# 1211/1211 [==============================] - 0s 142us/step - loss: 0.0641 - acc: 0.9810
# Training of node 5 complete

# %%
#Model chain
y_pred = []

X_feed = X_test.copy()
i = 0
for node in chain:
    print("Getting op from chain node ",i)
    node_name = "Node" + str(i)
    print("Shapes:\n X = {}".format(X_feed.shape))
    output = node.predict(X_feed)
    output = output.round().astype(int)
    y_pred.append(output)
    X_feed = np.append(X_feed,output,axis=1)
    i+=1
    #Updating X_feed
# Out:
# Getting op from chain node  0
# Shapes:
#  X = (1196, 294)
# Getting op from chain node  1
# Shapes:
#  X = (1196, 295)
# Getting op from chain node  2
# Shapes:
#  X = (1196, 296)
# Getting op from chain node  3
# Shapes:
#  X = (1196, 297)
# Getting op from chain node  4
# Shapes:
#  X = (1196, 298)
# Getting op from chain node  5
# Shapes:
#  X = (1196, 299)

# %%
predictions = np.array([0])
for i in y_pred:
    x = np.array(i)
    if predictions.shape == (1,):
        predictions = x
    else:
        predictions = np.append(predictions,x,axis=1)

# %%
from sklearn.metrics import accuracy_score,hamming_loss, log_loss, f1_score

# %%
# accuracy
print("Accuracy = ",accuracy_score(y_test,predictions))
print("Hamming accuracy = ",hamming_accuracy_score(y_test,predictions))
print("Hamming loss = ",hamming_loss(y_test,predictions))
print("Log loss = ",log_loss(y_test,predictions))
print("F1 score = ",f1_score(y_test,predictions,average='macro'))
# Out:
# Accuracy =  0.653846153846
# Hamming accuracy =  0.695652173913
# Hamming loss =  0.09866220735785954
# Log loss =  10.8188842272
# F1 score =  0.718752913558
