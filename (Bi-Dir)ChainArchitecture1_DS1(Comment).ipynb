# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_raw = pd.read_csv('dataset1_comments.csv')
#data_raw = data_raw.loc[np.random.choice(data_raw.index, size=2000)]
data = data_raw
data = data_raw.loc[np.random.choice(data_raw.index, size=2000)]
data.shape
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import re

import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
def cleanHtml(sentence):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', str(sentence))
    return cleantext


def cleanPunc(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    cleaned = cleaned.strip()
    cleaned = cleaned.replace("\n"," ")
    return cleaned


def keepAlpha(sentence):
    alpha_sent = ""
    for word in sentence.split():
        alpha_word = re.sub('[^a-z A-Z]+', ' ', word)
        alpha_sent += alpha_word
        alpha_sent += " "
    alpha_sent = alpha_sent.strip()
    return alpha_sent

# %%
data['comment_text'] = data['comment_text'].str.lower()
data['comment_text'] = data['comment_text'].apply(cleanHtml)
data['comment_text'] = data['comment_text'].apply(cleanPunc)
data['comment_text'] = data['comment_text'].apply(keepAlpha)
stop_words = set(stopwords.words('english'))
stop_words.update(['zero','one','two','three','four','five','six','seven','eight','nine','ten','may','also','across','among','beside','however','yet','within'])
re_stop_words = re.compile(r"\b(" + "|".join(stop_words) + ")\\W", re.I)
def removeStopWords(sentence):
    global re_stop_words
    return re_stop_words.sub(" ", sentence)

data['comment_text'] = data['comment_text'].apply(removeStopWords)
stemmer = SnowballStemmer("english")
def stemming(sentence):
    stemSentence = ""
    for word in sentence.split():
        stem = stemmer.stem(word)
        stemSentence += stem
        stemSentence += " "
    stemSentence = stemSentence.strip()
    return stemSentence

data['comment_text'] = data['comment_text'].apply(stemming)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data,test_size=0.30, shuffle=True)

train_text = train['comment_text']
test_text = test['comment_text']


from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(strip_accents='unicode', analyzer='word', ngram_range=(1,3), norm='l2',max_features=5000)
vectorizer.fit(train_text)
vectorizer.fit(test_text)

X_train = vectorizer.transform(train_text).toarray()
y_train = train.drop(labels = ['id','comment_text'], axis=1).values

X_test = vectorizer.transform(test_text).toarray()
y_test = test.drop(labels = ['id','comment_text'], axis=1).values

# %%
print("Train_X: ",X_train.shape)
print("Train_Y: ",y_train.shape)
print("Test_X: ",X_test.shape)
print("Test_Y: ",y_test.shape)
# Out:
# Train_X:  (1400, 5000)
# Train_Y:  (1400, 6)
# Test_X:  (600, 5000)
# Test_Y:  (600, 6)

# %%
def hamming_accuracy_score(y_true, y_pred, normalize=True, sample_weight=None):
    '''
    Compute the Hamming score (a.k.a. label-based accuracy) for the multi-label case
    http://stackoverflow.com/q/32239577/395857
    '''
    acc_list = []
    for i in range(y_true.shape[0]):
        set_true = set( np.where(y_true[i])[0] )
        set_pred = set( np.where(y_pred[i])[0] )
        #print('\nset_true: {0}'.format(set_true))
        #print('set_pred: {0}'.format(set_pred))
        tmp_a = None
        if len(set_true) == 0 and len(set_pred) == 0:
            tmp_a = 1
        else:
            tmp_a = len(set_true.intersection(set_pred))/float( len(set_true.union(set_pred)) )
        #print('tmp_a: {0}'.format(tmp_a))
        acc_list.append(tmp_a)
    return np.mean(acc_list)

# %% [markdown]
# ## Bidirectional Model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.backend.tensorflow_backend import clear_session
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
ENS_COUNT = 4
clear_session()

# %%
def create_c1node(X_feed,y_now):
    '''
    C1 node Architecture:
    attribute:512:256:1 [saperate for each class]
    loss: Binary crossentropy
    '''
    model = Sequential()
    model.add(Dense(512,activation='relu',input_shape=(X_feed.shape[1],),kernel_initializer='glorot_uniform'))
    model.add(Dropout(0.4))
    model.add(Dense(256,activation='relu',kernel_initializer='glorot_uniform'))
    model.add(Dropout(0.4))
    model.add(Dense(y_now.shape[1],activation='sigmoid',kernel_initializer='glorot_uniform'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    
    return model

# %%
ensembles_fwd = []
for j in range(ENS_COUNT//2):
    print("TRAINING ENSEMBLE {} :\n\n\n".format(j))
    #Model chain
    chain_forward = []

    #Training
    x_t,_,y_t,_ = train_test_split(X_train,y_train,test_size=0.4)
    X_feed = x_t.copy()
    for i in range(y_t.shape[1]):
        print("Training chain node ",i)
        y_now = y_t[:,[i,]].copy()
        print("Shapes:\n X = {} \n Y = {}".format(X_feed.shape,y_now.shape))

        node = create_c1node(X_feed,y_now)
        node.fit(X_feed,y_now,epochs=5,batch_size=50)
        print("Training of node {} complete\n\n".format(i))  
        #Checking accuracy of the node
        #---
        #Adding node to chain 
        chain_forward.append(node)
        #Updating X_feed
        X_feed = np.append(X_feed,y_now,axis=1)
    ensembles_fwd.append(chain_forward)
# Out:
# TRAINING ENSEMBLE 0 :
#
#
#
# Training chain node  0
# Shapes:
#  X = (840, 5000)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 21s 26ms/step - loss: 0.5013 - acc: 0.8690
# Epoch 2/5
# 840/840 [==============================] - 1s 737us/step - loss: 0.2893 - acc: 0.8940
# Epoch 3/5
# 840/840 [==============================] - 1s 741us/step - loss: 0.2112 - acc: 0.8940
# Epoch 4/5
# 840/840 [==============================] - 1s 735us/step - loss: 0.1654 - acc: 0.8940
# Epoch 5/5
# 840/840 [==============================] - 1s 736us/step - loss: 0.1328 - acc: 0.8940
# Training of node 0 complete
#
#
# Training chain node  1
# Shapes:
#  X = (840, 5001)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 1s 1ms/step - loss: 0.4386 - acc: 0.9464
# Epoch 2/5
# 840/840 [==============================] - 1s 740us/step - loss: 0.0752 - acc: 0.9845
# Epoch 3/5
# 840/840 [==============================] - 1s 744us/step - loss: 0.0414 - acc: 0.9845
# Epoch 4/5
# 840/840 [==============================] - 1s 739us/step - loss: 0.0280 - acc: 0.9845
# Epoch 5/5
# 840/840 [==============================] - 1s 741us/step - loss: 0.0222 - acc: 0.9845
# Training of node 1 complete
#
#
# Training chain node  2
# Shapes:
#  X = (840, 5002)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 1s 2ms/step - loss: 0.4713 - acc: 0.9083
# Epoch 2/5
# 840/840 [==============================] - 1s 744us/step - loss: 0.1537 - acc: 0.9417
# Epoch 3/5
# 840/840 [==============================] - 1s 742us/step - loss: 0.0941 - acc: 0.9417
# Epoch 4/5
# 840/840 [==============================] - 1s 743us/step - loss: 0.0676 - acc: 0.9476
# Epoch 5/5
# 840/840 [==============================] - 1s 741us/step - loss: 0.0537 - acc: 0.9774
# Training of node 2 complete
#
#
# Training chain node  3
# Shapes:
#  X = (840, 5003)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 1s 2ms/step - loss: 0.3894 - acc: 0.9810
# Epoch 2/5
# 840/840 [==============================] - 1s 742us/step - loss: 0.0175 - acc: 0.9988
# Epoch 3/5
# 840/840 [==============================] - 1s 743us/step - loss: 0.0095 - acc: 0.9988
# Epoch 4/5
# 840/840 [==============================] - 1s 742us/step - loss: 0.0068 - acc: 0.9988
# Epoch 5/5
# 840/840 [==============================] - 1s 743us/step - loss: 0.0059 - acc: 0.9988
# Training of node 3 complete
#
#
# Training chain node  4
# Shapes:
#  X = (840, 5004)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4703 - acc: 0.9119
# Epoch 2/5
# 840/840 [==============================] - 1s 752us/step - loss: 0.1242 - acc: 0.9536
# Epoch 3/5
# 840/840 [==============================] - 1s 744us/step - loss: 0.0708 - acc: 0.9536
# Epoch 4/5
# 840/840 [==============================] - 1s 746us/step - loss: 0.0517 - acc: 0.9667
# Epoch 5/5
# 840/840 [==============================] - 1s 740us/step - loss: 0.0401 - acc: 0.9881
# Training of node 4 complete
#
#
# Training chain node  5
# Shapes:
#  X = (840, 5005)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 1s 2ms/step - loss: 0.4204 - acc: 0.9643
# Epoch 2/5
# 840/840 [==============================] - 1s 740us/step - loss: 0.0696 - acc: 0.9917
# Epoch 3/5
# 840/840 [==============================] - 1s 739us/step - loss: 0.0396 - acc: 0.9917
# Epoch 4/5
# 840/840 [==============================] - 1s 742us/step - loss: 0.0229 - acc: 0.9917
# Epoch 5/5
# 840/840 [==============================] - 1s 738us/step - loss: 0.0174 - acc: 0.9917
# Training of node 5 complete
#
#
# TRAINING ENSEMBLE 1 :
#
#
#
# Training chain node  0
# Shapes:
#  X = (840, 5000)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 1s 2ms/step - loss: 0.4933 - acc: 0.8786
# Epoch 2/5
# 840/840 [==============================] - 1s 744us/step - loss: 0.2659 - acc: 0.9000
# Epoch 3/5
# 840/840 [==============================] - 1s 785us/step - loss: 0.2027 - acc: 0.9000
# Epoch 4/5
# 840/840 [==============================] - 1s 775us/step - loss: 0.1525 - acc: 0.9000
# Epoch 5/5
# 840/840 [==============================] - 1s 759us/step - loss: 0.1222 - acc: 0.9000
# Training of node 0 complete
#
#
# Training chain node  1
# Shapes:
#  X = (840, 5001)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4269 - acc: 0.9405
# Epoch 2/5
# 840/840 [==============================] - 1s 746us/step - loss: 0.0700 - acc: 0.9857
# Epoch 3/5
# 840/840 [==============================] - 1s 757us/step - loss: 0.0482 - acc: 0.9857
# Epoch 4/5
# 840/840 [==============================] - 1s 760us/step - loss: 0.0317 - acc: 0.9857
# Epoch 5/5
# 840/840 [==============================] - 1s 762us/step - loss: 0.0247 - acc: 0.9857
# Training of node 1 complete
#
#
# Training chain node  2
# Shapes:
#  X = (840, 5002)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4845 - acc: 0.8952
# Epoch 2/5
# 840/840 [==============================] - 1s 1ms/step - loss: 0.1666 - acc: 0.9333
# Epoch 3/5
# 840/840 [==============================] - 1s 1ms/step - loss: 0.0957 - acc: 0.9369
# Epoch 4/5
# 840/840 [==============================] - 1s 884us/step - loss: 0.0701 - acc: 0.9726 0s - loss: 0.0736 - acc: 0.96
# Epoch 5/5
# 840/840 [==============================] - 1s 883us/step - loss: 0.0468 - acc: 0.9940
# Training of node 2 complete
#
#
# Training chain node  3
# Shapes:
#  X = (840, 5003)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 2s 3ms/step - loss: 0.4101 - acc: 0.9583
# Epoch 2/5
# 840/840 [==============================] - 1s 791us/step - loss: 0.0150 - acc: 1.0000
# Epoch 3/5
# 840/840 [==============================] - 1s 790us/step - loss: 4.1480e-04 - acc: 1.0000
# Epoch 4/5
# 840/840 [==============================] - 1s 825us/step - loss: 1.7031e-04 - acc: 1.0000
# Epoch 5/5
# 840/840 [==============================] - 1s 794us/step - loss: 1.5643e-04 - acc: 1.0000
# Training of node 3 complete
#
#
# Training chain node  4
# Shapes:
#  X = (840, 5004)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4739 - acc: 0.9060
# Epoch 2/5
# 840/840 [==============================] - 1s 754us/step - loss: 0.1294 - acc: 0.9488
# Epoch 3/5
# 840/840 [==============================] - 1s 752us/step - loss: 0.0744 - acc: 0.9488
# Epoch 4/5
# 840/840 [==============================] - 1s 762us/step - loss: 0.0570 - acc: 0.9595
# Epoch 5/5
# 840/840 [==============================] - 1s 752us/step - loss: 0.0466 - acc: 0.9833
# Training of node 4 complete
#
#
# Training chain node  5
# Shapes:
#  X = (840, 5005)
#  Y = (840, 1)
# Epoch 1/5
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4260 - acc: 0.9500
# Epoch 2/5
# 840/840 [==============================] - 1s 744us/step - loss: 0.0647 - acc: 0.9881
# Epoch 3/5
# 840/840 [==============================] - 1s 760us/step - loss: 0.0383 - acc: 0.9881
# Epoch 4/5
# 840/840 [==============================] - 1s 755us/step - loss: 0.0250 - acc: 0.9881
# Epoch 5/5
# 840/840 [==============================] - 1s 756us/step - loss: 0.0198 - acc: 0.9881
# Training of node 5 complete

# %%
ensembles_rev = []
for j in range(ENS_COUNT//2):
    print("TRAINING ENSEMBLE {} :\n\n\n".format(j))
    #Model chain
    chain_reverse = []
    #Training
    x_t,_,y_t,_ = train_test_split(X_train,y_train,test_size=0.4)
    X_feed = x_t.copy()
    for i in range(1,y_t.shape[1]+1):
        print("Training chain node ",i)
        y_now = y_t[:,[-i,]].copy()
        print("Shapes:\n X = {} \n Y = {}".format(X_feed.shape,y_now.shape))

        node = create_c1node(X_feed,y_now)
        node.fit(X_feed,y_now,epochs=10,batch_size=50)
        print("Training of node {} complete\n\n".format(i))  
        #Checking accuracy of the node
        #---
        #Adding node to chain 
        chain_reverse.append(node)
        #Updating X_feed
        X_feed = np.append(X_feed,y_now,axis=1)
    ensembles_rev.append(chain_reverse)
# Out:
# TRAINING ENSEMBLE 0 :
#
#
#
# Training chain node  1
# Shapes:
#  X = (840, 5000)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4277 - acc: 0.9583
# Epoch 2/10
# 840/840 [==============================] - 1s 749us/step - loss: 0.0572 - acc: 0.9893
# Epoch 3/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0477 - acc: 0.9893
# Epoch 4/10
# 840/840 [==============================] - 1s 760us/step - loss: 0.0352 - acc: 0.9893
# Epoch 5/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.0286 - acc: 0.9893
# Epoch 6/10
# 840/840 [==============================] - 1s 761us/step - loss: 0.0235 - acc: 0.9893
# Epoch 7/10
# 840/840 [==============================] - 1s 752us/step - loss: 0.0204 - acc: 0.9893
# Epoch 8/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.0183 - acc: 0.9893
# Epoch 9/10
# 840/840 [==============================] - 1s 774us/step - loss: 0.0168 - acc: 0.9893
# Epoch 10/10
# 840/840 [==============================] - 1s 781us/step - loss: 0.0154 - acc: 0.9893
# Training of node 1 complete
#
#
# Training chain node  2
# Shapes:
#  X = (840, 5001)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4349 - acc: 0.9357
# Epoch 2/10
# 840/840 [==============================] - 1s 768us/step - loss: 0.1777 - acc: 0.9452
# Epoch 3/10
# 840/840 [==============================] - 1s 761us/step - loss: 0.1243 - acc: 0.9452
# Epoch 4/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0970 - acc: 0.9452
# Epoch 5/10
# 840/840 [==============================] - 1s 762us/step - loss: 0.0777 - acc: 0.9452
# Epoch 6/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0666 - acc: 0.9452
# Epoch 7/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0569 - acc: 0.9452
# Epoch 8/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0509 - acc: 0.9452
# Epoch 9/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0468 - acc: 0.9488
# Epoch 10/10
# 840/840 [==============================] - 1s 759us/step - loss: 0.0449 - acc: 0.9762
# Training of node 2 complete
#
#
# Training chain node  3
# Shapes:
#  X = (840, 5002)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 2ms/step - loss: 0.3988 - acc: 0.9833
# Epoch 2/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.0120 - acc: 1.0000
# Epoch 3/10
# 840/840 [==============================] - 1s 759us/step - loss: 3.9124e-04 - acc: 1.0000
# Epoch 4/10
# 840/840 [==============================] - 1s 760us/step - loss: 1.6293e-04 - acc: 1.0000
# Epoch 5/10
# 840/840 [==============================] - 1s 754us/step - loss: 1.1776e-04 - acc: 1.0000
# Epoch 6/10
# 840/840 [==============================] - 1s 756us/step - loss: 1.0288e-04 - acc: 1.0000
# Epoch 7/10
# 840/840 [==============================] - 1s 765us/step - loss: 1.1218e-04 - acc: 1.0000
# Epoch 8/10
# 840/840 [==============================] - 1s 758us/step - loss: 1.0232e-04 - acc: 1.0000
# Epoch 9/10
# 840/840 [==============================] - 1s 749us/step - loss: 8.1916e-05 - acc: 1.0000
# Epoch 10/10
# 840/840 [==============================] - 1s 761us/step - loss: 9.5282e-05 - acc: 1.0000
# Training of node 3 complete
#
#
# Training chain node  4
# Shapes:
#  X = (840, 5003)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4874 - acc: 0.8857
# Epoch 2/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.1776 - acc: 0.9333
# Epoch 3/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.1095 - acc: 0.9345
# Epoch 4/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.0797 - acc: 0.9524
# Epoch 5/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.0604 - acc: 0.9821
# Epoch 6/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.0393 - acc: 0.9869
# Epoch 7/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.0214 - acc: 0.9976
# Epoch 8/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.0124 - acc: 0.9976
# Epoch 9/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0067 - acc: 0.9988
# Epoch 10/10
# 840/840 [==============================] - 1s 757us/step - loss: 0.0042 - acc: 1.0000
# Training of node 4 complete
#
#
# Training chain node  5
# Shapes:
#  X = (840, 5004)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 2ms/step - loss: 0.4356 - acc: 0.9405
# Epoch 2/10
# 840/840 [==============================] - 1s 792us/step - loss: 0.0742 - acc: 0.9833 0s - loss: 0.1012 - acc:
# Epoch 3/10
# 840/840 [==============================] - 1s 805us/step - loss: 0.0407 - acc: 0.9833
# Epoch 4/10
# 840/840 [==============================] - 1s 785us/step - loss: 0.0282 - acc: 0.9833
# Epoch 5/10
# 840/840 [==============================] - 1s 773us/step - loss: 0.0230 - acc: 0.9833
# Epoch 6/10
# 840/840 [==============================] - 1s 780us/step - loss: 0.0205 - acc: 0.9833
# Epoch 7/10
# 840/840 [==============================] - 1s 776us/step - loss: 0.0183 - acc: 0.9833
# Epoch 8/10
# 840/840 [==============================] - 1s 773us/step - loss: 0.0168 - acc: 0.9833
# Epoch 9/10
# 840/840 [==============================] - 1s 761us/step - loss: 0.0159 - acc: 0.9833
# Epoch 10/10
# 840/840 [==============================] - 1s 766us/step - loss: 0.0140 - acc: 0.9893
# Training of node 5 complete
#
#
# Training chain node  6
# Shapes:
#  X = (840, 5005)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 2ms/step - loss: 0.5151 - acc: 0.8488
# Epoch 2/10
# 840/840 [==============================] - 1s 752us/step - loss: 0.2421 - acc: 0.8964
# Epoch 3/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.1495 - acc: 0.9476
# Epoch 4/10
# 840/840 [==============================] - 1s 762us/step - loss: 0.0943 - acc: 0.9548
# Epoch 5/10
# 840/840 [==============================] - 1s 772us/step - loss: 0.0463 - acc: 0.9833
# Epoch 6/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0283 - acc: 0.9952
# Epoch 7/10
# 840/840 [==============================] - 1s 752us/step - loss: 0.0160 - acc: 0.9976
# Epoch 8/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.0119 - acc: 0.9988
# Epoch 9/10
# 840/840 [==============================] - 1s 744us/step - loss: 0.0088 - acc: 0.9988
# Epoch 10/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0067 - acc: 0.9988
# Training of node 6 complete
#
#
# TRAINING ENSEMBLE 1 :
#
#
#
# Training chain node  1
# Shapes:
#  X = (840, 5000)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 2ms/step - loss: 0.3934 - acc: 0.9774
# Epoch 2/10
# 840/840 [==============================] - 1s 765us/step - loss: 0.0434 - acc: 0.9917
# Epoch 3/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0436 - acc: 0.9917
# Epoch 4/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0293 - acc: 0.9917
# Epoch 5/10
# 840/840 [==============================] - 1s 762us/step - loss: 0.0223 - acc: 0.9917
# Epoch 6/10
# 840/840 [==============================] - 1s 765us/step - loss: 0.0181 - acc: 0.9917
# Epoch 7/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.0148 - acc: 0.9917
# Epoch 8/10
# 840/840 [==============================] - 1s 760us/step - loss: 0.0130 - acc: 0.9917
# Epoch 9/10
# 840/840 [==============================] - 1s 762us/step - loss: 0.0119 - acc: 0.9917
# Epoch 10/10
# 840/840 [==============================] - 1s 761us/step - loss: 0.0116 - acc: 0.9917
# Training of node 1 complete
#
#
# Training chain node  2
# Shapes:
#  X = (840, 5001)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 3ms/step - loss: 0.4500 - acc: 0.9262
# Epoch 2/10
# 840/840 [==============================] - 1s 778us/step - loss: 0.1830 - acc: 0.9464
# Epoch 3/10
# 840/840 [==============================] - 1s 773us/step - loss: 0.1253 - acc: 0.9464
# Epoch 4/10
# 840/840 [==============================] - 1s 765us/step - loss: 0.0943 - acc: 0.9464
# Epoch 5/10
# 840/840 [==============================] - 1s 769us/step - loss: 0.0750 - acc: 0.9464
# Epoch 6/10
# 840/840 [==============================] - 1s 752us/step - loss: 0.0634 - acc: 0.9464
# Epoch 7/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0534 - acc: 0.9464
# Epoch 8/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0472 - acc: 0.9512
# Epoch 9/10
# 840/840 [==============================] - 1s 779us/step - loss: 0.0424 - acc: 0.9702
# Epoch 10/10
# 840/840 [==============================] - 1s 765us/step - loss: 0.0395 - acc: 0.9881
# Training of node 2 complete
#
#
# Training chain node  3
# Shapes:
#  X = (840, 5002)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 3ms/step - loss: 0.4076 - acc: 0.9667
# Epoch 2/10
# 840/840 [==============================] - 1s 752us/step - loss: 0.0228 - acc: 0.9988
# Epoch 3/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.0079 - acc: 0.9988
# Epoch 4/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0065 - acc: 0.9988
# Epoch 5/10
# 840/840 [==============================] - 1s 759us/step - loss: 0.0049 - acc: 0.9988
# Epoch 6/10
# 840/840 [==============================] - 1s 753us/step - loss: 0.0041 - acc: 0.9988
# Epoch 7/10
# 840/840 [==============================] - 1s 763us/step - loss: 0.0032 - acc: 0.9988
# Epoch 8/10
# 840/840 [==============================] - 1s 778us/step - loss: 0.0028 - acc: 0.9988
# Epoch 9/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.0020 - acc: 0.9988
# Epoch 10/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0017 - acc: 0.9988
# Training of node 3 complete
#
#
# Training chain node  4
# Shapes:
#  X = (840, 5003)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 3ms/step - loss: 0.4718 - acc: 0.9214
# Epoch 2/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.1610 - acc: 0.9405
# Epoch 3/10
# 840/840 [==============================] - 1s 765us/step - loss: 0.1031 - acc: 0.9405
# Epoch 4/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0769 - acc: 0.9488
# Epoch 5/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0601 - acc: 0.9810
# Epoch 6/10
# 840/840 [==============================] - 1s 759us/step - loss: 0.0453 - acc: 0.9869
# Epoch 7/10
# 840/840 [==============================] - 1s 765us/step - loss: 0.0276 - acc: 0.9964
# Epoch 8/10
# 840/840 [==============================] - 1s 759us/step - loss: 0.0144 - acc: 1.0000
# Epoch 9/10
# 840/840 [==============================] - 1s 761us/step - loss: 0.0073 - acc: 1.0000
# Epoch 10/10
# 840/840 [==============================] - 1s 780us/step - loss: 0.0038 - acc: 1.0000
# Training of node 4 complete
#
#
# Training chain node  5
# Shapes:
#  X = (840, 5004)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 2s 3ms/step - loss: 0.3944 - acc: 0.9690
# Epoch 2/10
# 840/840 [==============================] - 1s 763us/step - loss: 0.0604 - acc: 0.9845
# Epoch 3/10
# 840/840 [==============================] - 1s 759us/step - loss: 0.0390 - acc: 0.9845
# Epoch 4/10
# 840/840 [==============================] - 1s 757us/step - loss: 0.0249 - acc: 0.9845
# Epoch 5/10
# 840/840 [==============================] - 1s 759us/step - loss: 0.0211 - acc: 0.9845
# Epoch 6/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.0186 - acc: 0.9845
# Epoch 7/10
# 840/840 [==============================] - 1s 754us/step - loss: 0.0160 - acc: 0.9845
# Epoch 8/10
# 840/840 [==============================] - 1s 748us/step - loss: 0.0145 - acc: 0.9845
# Epoch 9/10
# 840/840 [==============================] - 1s 779us/step - loss: 0.0127 - acc: 0.9893
# Epoch 10/10
# 840/840 [==============================] - 1s 790us/step - loss: 0.0125 - acc: 0.9940
# Training of node 5 complete
#
#
# Training chain node  6
# Shapes:
#  X = (840, 5005)
#  Y = (840, 1)
# Epoch 1/10
# 840/840 [==============================] - 3s 3ms/step - loss: 0.5062 - acc: 0.8690
# Epoch 2/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.2244 - acc: 0.8964
# Epoch 3/10
# 840/840 [==============================] - 1s 763us/step - loss: 0.1506 - acc: 0.9369
# Epoch 4/10
# 840/840 [==============================] - 1s 762us/step - loss: 0.0944 - acc: 0.9631
# Epoch 5/10
# 840/840 [==============================] - 1s 761us/step - loss: 0.0528 - acc: 0.9810
# Epoch 6/10
# 840/840 [==============================] - 1s 757us/step - loss: 0.0294 - acc: 0.9940
# Epoch 7/10
# 840/840 [==============================] - 1s 761us/step - loss: 0.0193 - acc: 0.9940
# Epoch 8/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0159 - acc: 0.9976
# Epoch 9/10
# 840/840 [==============================] - 1s 756us/step - loss: 0.0125 - acc: 0.9976
# Epoch 10/10
# 840/840 [==============================] - 1s 755us/step - loss: 0.0129 - acc: 0.9964
# Training of node 6 complete

# %%
y_full_fw = []
y_full_re = []

for k in range(ENS_COUNT//2):
    print("\n\nENSEMBLE {}:\n\n".format(k+1))
    X_feed_fw = X_test.copy()
    X_feed_re = X_test.copy()
    j = 0
    #Model chain
    y_pred_fw = []
    y_pred_re = []
    for i in range(len(chain_forward)):
        node1 = ensembles_fwd[k][i]
        node2 = ensembles_rev[k][i]
        print("Getting op from chain node ",j)
        node_name = "Node" + str(i)
        print("Shapes:\n X = {}".format(X_feed_fw.shape))
        output_fw = node1.predict(X_feed_fw)
        output_fw_bin = output_fw.round().astype(int)
        output_rev = node2.predict(X_feed_re)
        output_rev_bin = output_rev.round().astype(int)
        y_pred_fw.append(output_fw)
        y_pred_re.append(output_rev)
        X_feed_fw = np.append(X_feed_fw,output_fw_bin,axis=1)
        X_feed_re = np.append(X_feed_re,output_rev_bin,axis=1)
        j+=1
    y_full_fw.append(y_pred_fw)
    y_full_re.append(y_pred_re)
        #Updating X_feed
# Out:
# ENSEMBLE 1:
#
#
# Getting op from chain node  0
# Shapes:
#  X = (600, 5000)
# Getting op from chain node  1
# Shapes:
#  X = (600, 5001)
# Getting op from chain node  2
# Shapes:
#  X = (600, 5002)
# Getting op from chain node  3
# Shapes:
#  X = (600, 5003)
# Getting op from chain node  4
# Shapes:
#  X = (600, 5004)
# Getting op from chain node  5
# Shapes:
#  X = (600, 5005)
#
#
# ENSEMBLE 2:
#
#
# Getting op from chain node  0
# Shapes:
#  X = (600, 5000)
# Getting op from chain node  1
# Shapes:
#  X = (600, 5001)
# Getting op from chain node  2
# Shapes:
#  X = (600, 5002)
# Getting op from chain node  3
# Shapes:
#  X = (600, 5003)
# Getting op from chain node  4
# Shapes:
#  X = (600, 5004)
# Getting op from chain node  5
# Shapes:
#  X = (600, 5005)

# %%
cross_chain_group = []
for j in range(ENS_COUNT//2):
    prediction = []
    y_pred_fw = y_full_fw[j].copy()
    y_pred_re = y_full_re[j].copy()
    fw = np.array(y_pred_fw)[:,:,0].transpose().copy()
    re = np.array(y_pred_re)[:,:,0].transpose().copy()
    for i in range(np.array(y_pred_fw)[:,:,0].transpose().shape[0]):
        fw_i = fw[i,:].reshape(1,-1)[0]
        re_i = re[i,:].reshape(1,-1)[0][::-1] 
        final = (fw_i+re_i)/2
        prediction.append(final)
    cross_chain_group.append(np.array(prediction))

# %%
#Adding all 5 results
total = None
for x in cross_chain_group:
    if total is None:
        total = x
    else:
        total = total + x
#Calculating the average
predictions = (total/(ENS_COUNT//2)).round().astype(int)

# %%
from sklearn.metrics import accuracy_score,hamming_loss, log_loss, f1_score

# %%
# accuracy
print("Accuracy = ",accuracy_score(y_test,predictions))
print("Hamming accuracy = ",hamming_accuracy_score(y_test,predictions))
print("Hamming loss = ",hamming_loss(y_test,predictions))
print("Log loss = ",log_loss(y_test,predictions))
print("F1 score = ",f1_score(y_test,predictions,average='macro'))
# Out:
# Accuracy =  0.906666666667
# Hamming accuracy =  0.912611111111
# Hamming loss =  0.03333333333333333
# Log loss =  1.6733330222
# F1 score =  0.0731120731121
