# %%
import numpy as np
import warnings
import sys
import pandas as pd
import scipy
from scipy.io import arff
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
data_train, meta = scipy.io.arff.loadarff('yeast-train.arff')
df_train = pd.DataFrame(data_train)
data_test, meta = scipy.io.arff.loadarff('yeast-test.arff')
df_test = pd.DataFrame(data_test)
df_test.head()
# Out:
#        Att1      Att2      Att3      Att4      Att5      Att6      Att7  \
# 0  0.004168 -0.170975 -0.156748 -0.142151  0.058781  0.026851  0.197719
# 1 -0.103956  0.011879 -0.098986 -0.054501 -0.007970  0.049113 -0.030580
# 2  0.509949  0.401709  0.293799  0.087714  0.011686 -0.006411 -0.006255
# 3  0.119092  0.004412 -0.002262  0.072254  0.044512 -0.051467  0.074686
# 4  0.042037  0.007054 -0.069483  0.081015 -0.048207  0.089446 -0.004947
#
#        Att8      Att9     Att10   ...     Class5  Class6  Class7  Class8  \
# 0  0.041850  0.066938 -0.056617   ...       b'0'    b'0'    b'1'    b'1'
# 1 -0.077933 -0.080529 -0.016267   ...       b'0'    b'0'    b'0'    b'0'
# 2  0.013646 -0.040666 -0.024447   ...       b'0'    b'0'    b'0'    b'0'
# 3 -0.007670  0.079438  0.062184   ...       b'0'    b'0'    b'0'    b'0'
# 4  0.064456 -0.133387  0.068878   ...       b'1'    b'1'    b'0'    b'0'
#
#    Class9  Class10  Class11  Class12  Class13  Class14
# 0    b'0'     b'0'     b'0'     b'1'     b'1'     b'0'
# 1    b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
# 2    b'0'     b'0'     b'0'     b'1'     b'1'     b'0'
# 3    b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
# 4    b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
#
# [5 rows x 117 columns]

# %%
X_train = df_train.iloc[:,:-14].values
y_train = df_train.iloc[:,-14:].values.astype(int)
X_test = df_test.iloc[:,:-14].values
y_test = df_test.iloc[:,-14:].values.astype(int)

# %%
print("Train_X: ",X_train.shape)
print("Train_Y: ",y_train.shape)
print("Test_X: ",X_test.shape)
print("Test_Y: ",y_test.shape)
# Out:
# Train_X:  (1500, 103)
# Train_Y:  (1500, 14)
# Test_X:  (917, 103)
# Test_Y:  (917, 14)

# %%
def hamming_accuracy_score(y_true, y_pred, normalize=True, sample_weight=None):
    '''
    Compute the Hamming score (a.k.a. label-based accuracy) for the multi-label case
    http://stackoverflow.com/q/32239577/395857
    '''
    acc_list = []
    for i in range(y_true.shape[0]):
        set_true = set( np.where(y_true[i])[0] )
        set_pred = set( np.where(y_pred[i])[0] )
        #print('\nset_true: {0}'.format(set_true))
        #print('set_pred: {0}'.format(set_pred))
        tmp_a = None
        if len(set_true) == 0 and len(set_pred) == 0:
            tmp_a = 1
        else:
            tmp_a = len(set_true.intersection(set_pred))/float( len(set_true.union(set_pred)) )
        #print('tmp_a: {0}'.format(tmp_a))
        acc_list.append(tmp_a)
    return np.mean(acc_list)

# %% [markdown]
# ## Chain Model type 1

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.backend.tensorflow_backend import clear_session
# Out:
# Using TensorFlow backend.

# %%
def create_c1node(X_feed,y_now):
    '''
    C1 node Architecture:
    attribute:512:256:1 [saperate for each class]
    loss: Binary crossentropy
    '''
    model = Sequential()
    model.add(Dense(512,activation='relu',input_shape=(X_feed.shape[1],),kernel_initializer='glorot_uniform',name='first'))
    model.add(Dropout(0.4))
    model.add(Dense(256,activation='relu',kernel_initializer='glorot_uniform',name='nretrain1'))
    model.add(Dropout(0.4))
    model.add(Dense(128,activation='relu',kernel_initializer='glorot_uniform',name='nretrain2'))
    model.add(Dropout(0.4))
    model.add(Dense(64,activation='relu',kernel_initializer='glorot_uniform',name='last'))
    model.add(Dropout(0.4))    
    model.add(Dense(y_now.shape[1],activation='sigmoid',kernel_initializer='glorot_uniform',name='output'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    return model

# %%
#Model chain
chain = []

#Training
X_feed = X_train.copy()
for i in range(y_train.shape[1]):
    print("Training chain node ",i)
    y_now = y_train[:,[i,]].copy()
    print("Shapes:\n X = {} \n Y = {}".format(X_feed.shape,y_now.shape))

    node = create_c1node(X_feed,y_now)
    node.fit(X_feed,y_now,epochs=10,batch_size=50)
    print("Training of node {} complete\n\n".format(i))  
    #Checking accuracy of the node
    #---
    #Adding node to chain 
    chain.append(node)
    #Updating X_feed
    X_feed = np.append(X_feed,y_now,axis=1)
# Out:
# Training chain node  0
# Shapes:
#  X = (1500, 103)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.6054 - acc: 0.6760
# Epoch 2/10
# 1500/1500 [==============================] - 0s 292us/step - loss: 0.5174 - acc: 0.7627
# Epoch 3/10
# 1500/1500 [==============================] - 0s 294us/step - loss: 0.4498 - acc: 0.8053
# Epoch 4/10
# 1500/1500 [==============================] - 0s 299us/step - loss: 0.3905 - acc: 0.8267
# Epoch 5/10
# 1500/1500 [==============================] - 0s 301us/step - loss: 0.3733 - acc: 0.8393
# Epoch 6/10
# 1500/1500 [==============================] - 0s 297us/step - loss: 0.3125 - acc: 0.8760
# Epoch 7/10
# 1500/1500 [==============================] - 0s 311us/step - loss: 0.2831 - acc: 0.8980
# Epoch 8/10
# 1500/1500 [==============================] - 0s 308us/step - loss: 0.2551 - acc: 0.9013
# Epoch 9/10
# 1500/1500 [==============================] - 0s 304us/step - loss: 0.1956 - acc: 0.9213
# Epoch 10/10
# 1500/1500 [==============================] - 0s 306us/step - loss: 0.1511 - acc: 0.9467
# Training of node 0 complete
#
#
# Training chain node  1
# Shapes:
#  X = (1500, 104)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5996 - acc: 0.7040
# Epoch 2/10
# 1500/1500 [==============================] - 0s 305us/step - loss: 0.4951 - acc: 0.7853
# Epoch 3/10
# 1500/1500 [==============================] - 0s 305us/step - loss: 0.4415 - acc: 0.8080
# Epoch 4/10
# 1500/1500 [==============================] - 0s 331us/step - loss: 0.4026 - acc: 0.8307
# Epoch 5/10
# 1500/1500 [==============================] - 1s 338us/step - loss: 0.3557 - acc: 0.8473
# Epoch 6/10
# 1500/1500 [==============================] - 0s 304us/step - loss: 0.3148 - acc: 0.8700
# Epoch 7/10
# 1500/1500 [==============================] - 0s 305us/step - loss: 0.2856 - acc: 0.8807
# Epoch 8/10
# 1500/1500 [==============================] - 0s 299us/step - loss: 0.2165 - acc: 0.9147
# Epoch 9/10
# 1500/1500 [==============================] - 0s 327us/step - loss: 0.1920 - acc: 0.9253
# Epoch 10/10
# 1500/1500 [==============================] - 0s 313us/step - loss: 0.1743 - acc: 0.9307
# Training of node 1 complete
#
#
# Training chain node  2
# Shapes:
#  X = (1500, 105)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5698 - acc: 0.6853
# Epoch 2/10
# 1500/1500 [==============================] - 0s 308us/step - loss: 0.4003 - acc: 0.8193
# Epoch 3/10
# 1500/1500 [==============================] - 0s 302us/step - loss: 0.3522 - acc: 0.8420
# Epoch 4/10
# 1500/1500 [==============================] - 0s 305us/step - loss: 0.3289 - acc: 0.8580
# Epoch 5/10
# 1500/1500 [==============================] - 0s 308us/step - loss: 0.2705 - acc: 0.8847
# Epoch 6/10
# 1500/1500 [==============================] - 1s 346us/step - loss: 0.2326 - acc: 0.9120
# Epoch 7/10
# 1500/1500 [==============================] - 0s 303us/step - loss: 0.2067 - acc: 0.9173
# Epoch 8/10
# 1500/1500 [==============================] - 1s 346us/step - loss: 0.1511 - acc: 0.9460
# Epoch 9/10
# 1500/1500 [==============================] - 0s 301us/step - loss: 0.1513 - acc: 0.9413
# Epoch 10/10
# 1500/1500 [==============================] - 0s 306us/step - loss: 0.1204 - acc: 0.9547
# Training of node 2 complete
#
#
# Training chain node  3
# Shapes:
#  X = (1500, 106)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4922 - acc: 0.7407
# Epoch 2/10
# 1500/1500 [==============================] - 0s 296us/step - loss: 0.2768 - acc: 0.8873
# Epoch 3/10
# 1500/1500 [==============================] - 0s 297us/step - loss: 0.1938 - acc: 0.9280
# Epoch 4/10
# 1500/1500 [==============================] - 0s 295us/step - loss: 0.1674 - acc: 0.9327
# Epoch 5/10
# 1500/1500 [==============================] - 0s 296us/step - loss: 0.1593 - acc: 0.9387
# Epoch 6/10
# 1500/1500 [==============================] - 0s 301us/step - loss: 0.1289 - acc: 0.9507
# Epoch 7/10
# 1500/1500 [==============================] - 0s 298us/step - loss: 0.1016 - acc: 0.9613
# Epoch 8/10
# 1500/1500 [==============================] - 0s 299us/step - loss: 0.0934 - acc: 0.9593
# Epoch 9/10
# 1500/1500 [==============================] - 0s 291us/step - loss: 0.0678 - acc: 0.9713
# Epoch 10/10
# 1500/1500 [==============================] - 0s 300us/step - loss: 0.0542 - acc: 0.9807
# Training of node 3 complete
#
#
# Training chain node  4
# Shapes:
#  X = (1500, 107)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5381 - acc: 0.7253
# Epoch 2/10
# 1500/1500 [==============================] - 0s 312us/step - loss: 0.3957 - acc: 0.8400
# Epoch 3/10
# 1500/1500 [==============================] - 0s 314us/step - loss: 0.3290 - acc: 0.8613
# Epoch 4/10
# 1500/1500 [==============================] - 0s 313us/step - loss: 0.2850 - acc: 0.8907
# Epoch 5/10
# 1500/1500 [==============================] - 0s 300us/step - loss: 0.2809 - acc: 0.8847
# Epoch 6/10
# 1500/1500 [==============================] - 0s 322us/step - loss: 0.2346 - acc: 0.9093
# Epoch 7/10
# 1500/1500 [==============================] - 0s 314us/step - loss: 0.1921 - acc: 0.9253
# Epoch 8/10
# 1500/1500 [==============================] - 0s 295us/step - loss: 0.1739 - acc: 0.9307
# Epoch 9/10
# 1500/1500 [==============================] - 0s 317us/step - loss: 0.1461 - acc: 0.9473
# Epoch 10/10
# 1500/1500 [==============================] - 0s 319us/step - loss: 0.1164 - acc: 0.9580
# Training of node 4 complete
#
#
# Training chain node  5
# Shapes:
#  X = (1500, 108)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.4486 - acc: 0.7960
# Epoch 2/10
# 1500/1500 [==============================] - 0s 325us/step - loss: 0.2265 - acc: 0.9193
# Epoch 3/10
# 1500/1500 [==============================] - 0s 306us/step - loss: 0.1637 - acc: 0.9400
# Epoch 4/10
# 1500/1500 [==============================] - 0s 308us/step - loss: 0.1360 - acc: 0.9487
# Epoch 5/10
# 1500/1500 [==============================] - 0s 310us/step - loss: 0.0999 - acc: 0.9667
# Epoch 6/10
# 1500/1500 [==============================] - 0s 320us/step - loss: 0.0836 - acc: 0.9673
# Epoch 7/10
# 1500/1500 [==============================] - 0s 318us/step - loss: 0.0497 - acc: 0.9800
# Epoch 8/10
# 1500/1500 [==============================] - 0s 321us/step - loss: 0.0818 - acc: 0.9687
# Epoch 9/10
# 1500/1500 [==============================] - 1s 408us/step - loss: 0.0474 - acc: 0.9833
# Epoch 10/10
# 1500/1500 [==============================] - 0s 322us/step - loss: 0.0332 - acc: 0.9860
# Training of node 5 complete
#
#
# Training chain node  6
# Shapes:
#  X = (1500, 109)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4252 - acc: 0.8113
# Epoch 2/10
# 1500/1500 [==============================] - 0s 303us/step - loss: 0.2981 - acc: 0.8293
# Epoch 3/10
# 1500/1500 [==============================] - 0s 314us/step - loss: 0.2515 - acc: 0.9000
# Epoch 4/10
# 1500/1500 [==============================] - 0s 308us/step - loss: 0.1931 - acc: 0.9187
# Epoch 5/10
# 1500/1500 [==============================] - 0s 318us/step - loss: 0.1512 - acc: 0.9400
# Epoch 6/10
# 1500/1500 [==============================] - 0s 298us/step - loss: 0.1508 - acc: 0.9453
# Epoch 7/10
# 1500/1500 [==============================] - 0s 317us/step - loss: 0.0909 - acc: 0.9640
# Epoch 8/10
# 1500/1500 [==============================] - 0s 308us/step - loss: 0.0877 - acc: 0.9667
# Epoch 9/10
# 1500/1500 [==============================] - 0s 302us/step - loss: 0.0654 - acc: 0.9740
# Epoch 10/10
# 1500/1500 [==============================] - 0s 301us/step - loss: 0.0557 - acc: 0.9773
# Training of node 6 complete
#
#
# Training chain node  7
# Shapes:
#  X = (1500, 110)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4278 - acc: 0.8073
# Epoch 2/10
# 1500/1500 [==============================] - 0s 299us/step - loss: 0.2513 - acc: 0.9267
# Epoch 3/10
# 1500/1500 [==============================] - 0s 317us/step - loss: 0.2140 - acc: 0.9320
# Epoch 4/10
# 1500/1500 [==============================] - 0s 308us/step - loss: 0.1795 - acc: 0.9387
# Epoch 5/10
# 1500/1500 [==============================] - 0s 312us/step - loss: 0.1561 - acc: 0.9400
# Epoch 6/10
# 1500/1500 [==============================] - 0s 308us/step - loss: 0.1309 - acc: 0.9540
# Epoch 7/10
# 1500/1500 [==============================] - 0s 298us/step - loss: 0.1081 - acc: 0.9560
# Epoch 8/10
# 1500/1500 [==============================] - 0s 307us/step - loss: 0.0931 - acc: 0.9613
# Epoch 9/10
# 1500/1500 [==============================] - 0s 305us/step - loss: 0.0569 - acc: 0.9793
# Epoch 10/10
# 1500/1500 [==============================] - 0s 306us/step - loss: 0.0485 - acc: 0.9840
# Training of node 7 complete
#
#
# Training chain node  8
# Shapes:
#  X = (1500, 111)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3218 - acc: 0.9107
# Epoch 2/10
# 1500/1500 [==============================] - 0s 316us/step - loss: 0.1589 - acc: 0.9347
# Epoch 3/10
# 1500/1500 [==============================] - 0s 320us/step - loss: 0.1137 - acc: 0.9353
# Epoch 4/10
# 1500/1500 [==============================] - 0s 319us/step - loss: 0.0918 - acc: 0.9593
# Epoch 5/10
# 1500/1500 [==============================] - 0s 321us/step - loss: 0.0637 - acc: 0.9813
# Epoch 6/10
# 1500/1500 [==============================] - 0s 315us/step - loss: 0.0422 - acc: 0.9873
# Epoch 7/10
# 1500/1500 [==============================] - 0s 323us/step - loss: 0.0298 - acc: 0.9913
# Epoch 8/10
# 1500/1500 [==============================] - 0s 324us/step - loss: 0.0209 - acc: 0.9933
# Epoch 9/10
# 1500/1500 [==============================] - 0s 310us/step - loss: 0.0202 - acc: 0.9907
# Epoch 10/10
# 1500/1500 [==============================] - 0s 316us/step - loss: 0.0252 - acc: 0.9920
# Training of node 8 complete
#
#
# Training chain node  9
# Shapes:
#  X = (1500, 112)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3604 - acc: 0.8753
# Epoch 2/10
# 1500/1500 [==============================] - 0s 321us/step - loss: 0.2847 - acc: 0.8927
# Epoch 3/10
# 1500/1500 [==============================] - 0s 315us/step - loss: 0.2453 - acc: 0.8933
# Epoch 4/10
# 1500/1500 [==============================] - 0s 315us/step - loss: 0.2188 - acc: 0.8960
# Epoch 5/10
# 1500/1500 [==============================] - 0s 318us/step - loss: 0.1835 - acc: 0.9187
# Epoch 6/10
# 1500/1500 [==============================] - 0s 323us/step - loss: 0.1403 - acc: 0.9507 0s - loss: 0.1435 - acc:
# Epoch 7/10
# 1500/1500 [==============================] - 0s 321us/step - loss: 0.1041 - acc: 0.9560
# Epoch 8/10
# 1500/1500 [==============================] - 0s 317us/step - loss: 0.0891 - acc: 0.9673
# Epoch 9/10
# 1500/1500 [==============================] - 0s 321us/step - loss: 0.0714 - acc: 0.9753
# Epoch 10/10
# 1500/1500 [==============================] - 0s 322us/step - loss: 0.0560 - acc: 0.9827
# Training of node 9 complete
#
#
# Training chain node  10
# Shapes:
#  X = (1500, 113)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3499 - acc: 0.8640
# Epoch 2/10
# 1500/1500 [==============================] - 0s 301us/step - loss: 0.1688 - acc: 0.9207
# Epoch 3/10
# 1500/1500 [==============================] - 0s 310us/step - loss: 0.1162 - acc: 0.9627
# Epoch 4/10
# 1500/1500 [==============================] - 0s 304us/step - loss: 0.0838 - acc: 0.9707
# Epoch 5/10
# 1500/1500 [==============================] - 1s 335us/step - loss: 0.0637 - acc: 0.9820
# Epoch 6/10
# 1500/1500 [==============================] - 0s 322us/step - loss: 0.0553 - acc: 0.9787
# Epoch 7/10
# 1500/1500 [==============================] - 0s 318us/step - loss: 0.0336 - acc: 0.9867
# Epoch 8/10
# 1500/1500 [==============================] - 0s 311us/step - loss: 0.0312 - acc: 0.9907
# Epoch 9/10
# 1500/1500 [==============================] - 0s 317us/step - loss: 0.0214 - acc: 0.9913
# Epoch 10/10
# 1500/1500 [==============================] - 0s 321us/step - loss: 0.0157 - acc: 0.9953
# Training of node 10 complete
#
#
# Training chain node  11
# Shapes:
#  X = (1500, 114)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5548 - acc: 0.7387
# Epoch 2/10
# 1500/1500 [==============================] - 0s 317us/step - loss: 0.5053 - acc: 0.7527
# Epoch 3/10
# 1500/1500 [==============================] - 0s 314us/step - loss: 0.4848 - acc: 0.7560
# Epoch 4/10
# 1500/1500 [==============================] - 0s 319us/step - loss: 0.4580 - acc: 0.7673
# Epoch 5/10
# 1500/1500 [==============================] - 0s 332us/step - loss: 0.4211 - acc: 0.7940
# Epoch 6/10
# 1500/1500 [==============================] - 0s 319us/step - loss: 0.4080 - acc: 0.8040
# Epoch 7/10
# 1500/1500 [==============================] - 0s 310us/step - loss: 0.3452 - acc: 0.8440
# Epoch 8/10
# 1500/1500 [==============================] - 0s 318us/step - loss: 0.3008 - acc: 0.8667
# Epoch 9/10
# 1500/1500 [==============================] - 0s 313us/step - loss: 0.2528 - acc: 0.8913
# Epoch 10/10
# 1500/1500 [==============================] - 0s 331us/step - loss: 0.2163 - acc: 0.9120
# Training of node 11 complete
#
#
# Training chain node  12
# Shapes:
#  X = (1500, 115)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3295 - acc: 0.8320
# Epoch 2/10
# 1500/1500 [==============================] - ETA: 0s - loss: 0.0501 - acc: 0.991 - 0s 330us/step - loss: 0.0487 - acc: 0.9913
# Epoch 3/10
# 1500/1500 [==============================] - 0s 320us/step - loss: 0.0194 - acc: 0.9933
# Epoch 4/10
# 1500/1500 [==============================] - 0s 328us/step - loss: 0.0148 - acc: 0.9953
# Epoch 5/10
# 1500/1500 [==============================] - 0s 315us/step - loss: 0.0142 - acc: 0.9960
# Epoch 6/10
# 1500/1500 [==============================] - 0s 309us/step - loss: 0.0095 - acc: 0.9967
# Epoch 7/10
# 1500/1500 [==============================] - 0s 319us/step - loss: 0.0033 - acc: 0.9980
# Epoch 8/10
# 1500/1500 [==============================] - 0s 323us/step - loss: 0.0023 - acc: 0.9987
# Epoch 9/10
# 1500/1500 [==============================] - 0s 320us/step - loss: 0.0013 - acc: 1.0000
# Epoch 10/10
# 1500/1500 [==============================] - 0s 319us/step - loss: 1.5475e-04 - acc: 1.0000
# Training of node 12 complete
#
#
# Training chain node  13
# Shapes:
#  X = (1500, 116)
#  Y = (1500, 1)
# Epoch 1/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1595 - acc: 0.9740
# Epoch 2/10
# 1500/1500 [==============================] - 0s 317us/step - loss: 0.0566 - acc: 0.9860
# Epoch 3/10
# 1500/1500 [==============================] - 0s 320us/step - loss: 0.0436 - acc: 0.9860
# Epoch 4/10
# 1500/1500 [==============================] - 0s 329us/step - loss: 0.0357 - acc: 0.9860
# Epoch 5/10
# 1500/1500 [==============================] - 0s 328us/step - loss: 0.0284 - acc: 0.9860
# Epoch 6/10
# 1500/1500 [==============================] - 0s 317us/step - loss: 0.0225 - acc: 0.9860
# Epoch 7/10
# 1500/1500 [==============================] - 0s 321us/step - loss: 0.0166 - acc: 0.9860
# Epoch 8/10
# 1500/1500 [==============================] - 0s 333us/step - loss: 0.0148 - acc: 0.9860
# Epoch 9/10
# 1500/1500 [==============================] - 0s 326us/step - loss: 0.0128 - acc: 0.9880
# Epoch 10/10
# 1500/1500 [==============================] - 0s 325us/step - loss: 0.0118 - acc: 0.9947
# Training of node 13 complete

# %%
#Model chain
y_pred = []

X_feed = X_test.copy()
i = 0
for node in chain:
    print("Getting op from chain node ",i)
    node_name = "Node" + str(i)
    print("Shapes:\n X = {}".format(X_feed.shape))
    output = node.predict(X_feed)
    output = output.round().astype(int)
    y_pred.append(output)
    X_feed = np.append(X_feed,output,axis=1)
    i+=1
    #Updating X_feed
# Out:
# Getting op from chain node  0
# Shapes:
#  X = (917, 103)
# Getting op from chain node  1
# Shapes:
#  X = (917, 104)
# Getting op from chain node  2
# Shapes:
#  X = (917, 105)
# Getting op from chain node  3
# Shapes:
#  X = (917, 106)
# Getting op from chain node  4
# Shapes:
#  X = (917, 107)
# Getting op from chain node  5
# Shapes:
#  X = (917, 108)
# Getting op from chain node  6
# Shapes:
#  X = (917, 109)
# Getting op from chain node  7
# Shapes:
#  X = (917, 110)
# Getting op from chain node  8
# Shapes:
#  X = (917, 111)
# Getting op from chain node  9
# Shapes:
#  X = (917, 112)
# Getting op from chain node  10
# Shapes:
#  X = (917, 113)
# Getting op from chain node  11
# Shapes:
#  X = (917, 114)
# Getting op from chain node  12
# Shapes:
#  X = (917, 115)
# Getting op from chain node  13
# Shapes:
#  X = (917, 116)

# %%
predictions = np.array([0])
for i in y_pred:
    x = np.array(i)
    if predictions.shape == (1,):
        predictions = x
    else:
        predictions = np.append(predictions,x,axis=1)

# %%
# accuracy
from sklearn.metrics import hamming_loss, log_loss, f1_score,accuracy_score
print("Accuracy = ",accuracy_score(y_test,predictions))
print("Hamming accuracy = ",hamming_accuracy_score(y_test,predictions))
print("Hamming loss = ",hamming_loss(y_test,predictions))
print("Log loss = ",log_loss(y_test,predictions))
print("F1 score = ",f1_score(y_test,predictions,average='macro'))
# Out:
# Accuracy =  0.212649945474
# Hamming accuracy =  0.467030446229
# Hamming loss =  0.23780962766786104
# Log loss =  69.8946798143
# F1 score =  0.430576487903
